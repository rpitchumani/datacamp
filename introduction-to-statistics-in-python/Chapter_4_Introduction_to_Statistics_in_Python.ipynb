# %% [markdown]
# # Introduction to Statistics in Python

# %% [markdown]
# ## Chapter 4: Correlation and Experimental Design

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm, poisson, expon
import seaborn as sns
import matplotlib.pyplot as plt

# %%
world_happiness = pd.read_csv("world_happiness.csv")
world_happiness
# Out:
#      Unnamed: 0                   country  social_support  freedom  \
# 0             1                   Finland             2.0      5.0
# 1             2                   Denmark             4.0      6.0
# 2             3                    Norway             3.0      3.0
# 3             4                   Iceland             1.0      7.0
# 4             5               Netherlands            15.0     19.0
# ..          ...                       ...             ...      ...
# 138         139                    Rwanda           144.0     21.0
# 139         140                  Tanzania           131.0     78.0
# 140         141               Afghanistan           151.0    155.0
# 141         142  Central African Republic           155.0    133.0
# 142         143               South Sudan           148.0    154.0
#
#      corruption  generosity  gdp_per_cap  life_exp  happiness_score
# 0           4.0        47.0        42400      81.8              155
# 1           3.0        22.0        48300      81.0              154
# 2           8.0        11.0        66300      82.6              153
# 3          45.0         3.0        47900      83.0              152
# 4          12.0         7.0        50500      81.8              151
# ..          ...         ...          ...       ...              ...
# 138         2.0        90.0         2110      69.1                4
# 139        34.0        49.0         2980      67.7                3
# 140       136.0       137.0         1760      64.1                2
# 141       122.0       113.0          794      52.9                1
# 142        61.0        85.0         1860      59.7                0
#
# [143 rows x 9 columns]

# %%
# Create a scatterplot of happiness_score vs. life_exp and show
sns.scatterplot(data=world_happiness, x="life_exp", y="happiness_score")
# Show plot
plt.show()

# %%
# Create scatterplot of happiness_score vs life_exp with trendline
sns.lmplot(data=world_happiness, x="life_exp", y="happiness_score", ci=None)
# Show plot
plt.show()

# %%
# Correlation between life_exp and happiness_score
cor = world_happiness["life_exp"].corr(world_happiness["happiness_score"])
print(cor)
# Out:
# 0.7802249053272062

# %% [markdown]
# Transformations for making relationships linear
#
# - log transformation ```log(x)```
# - square root transformation ```sqrt(x)```
# - reciprocal transformation ```1/x```

# %%
# Scatterplot of gdp_per_cap and life_exp
sns.scatterplot(data=world_happiness, x="gdp_per_cap", y="life_exp")

# Show plot
plt.show()

# %%
# Correlation between gdp_per_cap and life_exp
cor = world_happiness["gdp_per_cap"].corr(world_happiness["life_exp"])

print(cor)
# Out:
# 0.7019547642148012

# %%
# Scatterplot of happiness_score vs. gdp_per_cap
sns.scatterplot(data=world_happiness, x="gdp_per_cap", y="happiness_score")

plt.show()

# Calculate correlation
cor = world_happiness["gdp_per_cap"].corr(world_happiness["happiness_score"])
print(cor)
# Out:
# 0.727973301222298

# %%
# Create log_gdp_per_cap column
world_happiness['log_gdp_per_cap'] = np.log(world_happiness["gdp_per_cap"])

# Scatterplot of happiness_score vs. log_gdp_per_cap
sns.scatterplot(data=world_happiness,
                x='log_gdp_per_cap',
                y="happiness_score")
plt.show()

# Calculate correlation
cor = world_happiness['log_gdp_per_cap'].corr(world_happiness["happiness_score"])
print(cor)
# Out:
# 0.8043146004918288

# %%
world_happiness = pd.read_csv("world_happiness_add_sugar.csv")
world_happiness
# Out:
#      Unnamed: 0                   country  social_support  freedom  \
# 0             1                   Finland               2        5
# 1             2                   Denmark               4        6
# 2             3                    Norway               3        3
# 3             4                   Iceland               1        7
# 4             5               Netherlands              15       19
# ..          ...                       ...             ...      ...
# 128         129                     Yemen             100      147
# 129         130                    Rwanda             144       21
# 130         131                  Tanzania             131       78
# 131         132               Afghanistan             151      155
# 132         133  Central African Republic             155      133
#
#      corruption  generosity  gdp_per_cap  life_exp  happiness_score  \
# 0           4.0          47        42400      81.8              155
# 1           3.0          22        48300      81.0              154
# 2           8.0          11        66300      82.6              153
# 3          45.0           3        47900      83.0              152
# 4          12.0           7        50500      81.8              151
# ..          ...         ...          ...       ...              ...
# 128        83.0         155         2340      68.1                5
# 129         2.0          90         2110      69.1                4
# 130        34.0          49         2980      67.7                3
# 131       136.0         137         1760      64.1                2
# 132       122.0         113          794      52.9                1
#
#      grams_sugar_per_day
# 0                   86.8
# 1                  152.0
# 2                  120.0
# 3                  132.0
# 4                  122.0
# ..                   ...
# 128                 77.9
# 129                 14.1
# 130                 28.0
# 131                 24.5
# 132                 22.4
#
# [133 rows x 10 columns]

# %%
# Scatterplot of grams_sugar_per_day and happiness_score
sns.scatterplot(data=world_happiness, x="grams_sugar_per_day", y="happiness_score")
plt.show()

# Correlation between grams_sugar_per_day and happiness_score
cor = world_happiness["grams_sugar_per_day"].corr(world_happiness["happiness_score"])
print(cor)
# Out:
# 0.6939100021829633
